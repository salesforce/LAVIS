# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.ticker

import numpy as np
import pandas as pd
import seaborn as sns
import humanize
from http import HTTPStatus
# HTTP Status codes:
def try_status(status):
    try:
        HTTPStatus(status)
        return True
    except:
        return False
def http_label(status):
    # 451 is missing...
    if status == 451:
        return "Unavailable_for_Legal_Reasons (451)"
    if not try_status(status):
        return "Other Unexpected Status (%s)" % status
    return "%s (%s)" % (str(HTTPStatus(status)).split('.')[1].title(), status)

def filesize(size, pos):
    return humanize.naturalsize(np.exp(size))

# %% [markdown]
# # Validation set Images (Downloaded):

# %%
df = pd.read_csv('downloaded_validation_report.tsv.gz', compression='gzip', sep='\t', names=["url","folder","status","mimetype","size","file","headers"])
df.sample(10)
# Out:
#                                                      url      folder  status  \
# 8747   http://cdn3.creativecirclemedia.com/rhodybeat/...  validation     200
# 14853  http://l7.alamy.com/zooms/20aa0087d6b44b4a9960...  validation     200
# 5785   https://static1.squarespace.com/static/542d78f...  validation     200
# 208    https://i.pinimg.com/736x/fe/52/a3/fe52a3c3acd...  validation     200
# 946    http://l7.alamy.com/zooms/c7efd9213c354558bc94...  validation     200
# 6595   https://i.pinimg.com/736x/fb/11/15/fb1115a5019...  validation     200
# 5589   http://i.dailymail.co.uk/i/pix/2012/08/09/arti...  validation     200
# 11799  https://triciaannemitchell.files.wordpress.com...  validation     200
# 242    http://cdn3.theinertia.com/wp-content/gallery/...  validation     200
# 739    https://i.pinimg.com/736x/66/53/e7/6653e792359...  validation     200
#
#          mimetype       size                   file  \
# 8747   image/jpeg  1427169.0  validation/1903725124
# 14853  image/jpeg   171046.0  validation/2799776854
# 5785   image/jpeg    91384.0  validation/2370121806
# 208    image/jpeg    39820.0  validation/1144640680
# 946    image/jpeg   126338.0   validation/201175022
# 6595   image/jpeg   369681.0  validation/2516586865
# 5589   image/jpeg   149063.0  validation/1063005072
# 11799  image/jpeg    57199.0  validation/1393368654
# 242    image/jpeg    92317.0  validation/2123666558
# 739    image/jpeg    90451.0   validation/715087014
#
#                                                  headers
# 8747   {'Date': 'Wed, 23 Jan 2019 21:52:57 GMT', 'Ser...
# 14853  {'access-control-allow-origin': '*', 'cache-co...
# 5785   {'X-ServedBy': 'cdn028', 'Timing-Allow-Origin'...
# 208    {'ETag': '"43a78f3b45a0ab3d185a31a90edf1672"',...
# 946    {'access-control-allow-origin': '*', 'cache-co...
# 6595   {'ETag': '"86a3b5d8d64dd93612e84c3a15bb499f"',...
# 5589   {'Server': 'Apache', 'ETag': '"d498595befbe6a8...
# 11799  {'Server': 'nginx', 'Date': 'Wed, 23 Jan 2019 ...
# 242    {'Date': 'Wed, 23 Jan 2019 21:51:21 GMT', 'Con...
# 739    {'ETag': '"027718b5b6230eceff4bb299df84d783"',...

# %%
pd.DataFrame(df.groupby('mimetype')['url'].count()).reset_index(level=0).sort_values(by='url', ascending=False)
# Out:
#         mimetype    url
# 1     image/jpeg  14736
# 4      text/html     51
# 2      image/png      6
# 0      image/gif      3
# 6     text/x-php      3
# 3  inode/x-empty      2
# 5     text/plain      1

# %%
by_status = df[df['status']!=200][['status','url']]
by_status = by_status.groupby('status').count()
by_status = pd.DataFrame(by_status).reset_index(level=0)
by_status['status'] = by_status['status'].apply(lambda x: http_label(x))
by_status.set_index("status",drop=True,inplace=True)
by_status.sort_values(by='url').plot.barh()
by_status.sort_values(by='url',ascending=False)
# Out:
#                              url
# status
# Not_Found (404)              329
# Request_Timeout (408)        289
# Forbidden (403)              257
# Method_Not_Allowed (405)     113
# Service_Unavailable (503)     16
# Bad_Request (400)             14
# Internal_Server_Error (500)    6
# Gone (410)                     5
# Unepected (520)                4
# No_Content (204)               2
# Unauthorized (401)             1
# Bad_Gateway (502)              1
# Unepected (520)                1

# %%
# File Sizes:
file_sizes = np.log(df[(df['size']> 0) & (df['mimetype'].str.contains('image'))]['size'].dropna())
print(len(file_sizes), 'images')

formatter = matplotlib.ticker.FuncFormatter(filesize)
plt.figure(figsize=(14,8))
ax = sns.violinplot(x=file_sizes, orient='v', inner='quartile', bw=0.01, palette='Set2')
ax.yaxis.set_major_formatter(formatter)
ax.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(1))
plt.show()
# Out:
# 14745 images

# %% [markdown]
# # Training set images (HEAD requests only, messier data from http headers)

# %%
df = pd.read_csv('downloaded_training_report_headers.tsv.gz', compression='gzip', sep='\t', names=["file","folder","headers","mimetype","size","status","url"])
df.sample(10)
# Out:
#                         file    folder  \
# 1046910  training/2514867496  training
# 2547807  training/2354229153  training
# 567325   training/2278417944  training
# 282403    training/384554288  training
# 745486   training/4237784938  training
# 1217623  training/1793512025  training
# 3307864  training/4048445692  training
# 3044538  training/3445721549  training
# 2182076   training/627212125  training
# 1504394  training/3727733594  training
#
#                                                    headers    mimetype  \
# 1046910  {'access-control-allow-origin': '*', 'cache-co...  image/jpeg
# 2547807  {'ETag': '"0386ea02b28cd4feb1b56c130cf25dec"',...  image/jpeg
# 567325   {'Server': 'Apache', 'ETag': '"989757fc651756f...  image/jpeg
# 282403   {'Date': 'Thu, 24 Jan 2019 23:43:42 GMT', 'Ser...  image/jpeg
# 745486   {'Last-Modified': 'Tue, 12 Dec 2017 19:03:05 G...  image/jpeg
# 1217623  {'access-control-allow-origin': '*', 'cache-co...  image/jpeg
# 3307864  {'Cache-Control': 'public,max-age=315360000', ...  image/jpeg
# 3044538  {'Server': 'Apache', 'ETag': '"9fb6ca35ebbb138...  image/jpeg
# 2182076  {'Server': 'Apache', 'ETag': '"1797bd2c5371f91...  image/jpeg
# 1504394  {'access-control-allow-origin': '*', 'cache-co...  image/jpeg
#
#              size  status                                                url
# 1046910       NaN     200  http://l7.alamy.com/zooms/a0035bc239bf44d3996e...
# 2547807   45379.0     200  https://i.pinimg.com/736x/20/78/a8/2078a8bc21b...
# 567325   118953.0     200  http://i.dailymail.co.uk/i/pix/2015/08/10/16/2...
# 282403        NaN     200  https://www.exlinguo.com/sites/default/files/p...
# 745486   128594.0     200  http://www.abc.net.au/news/image/9249844-3x2-9...
# 1217623       NaN     200  http://l7.alamy.com/zooms/c57a98d6ac2b4931b24d...
# 3307864       NaN     200  https://envato-shoebox-0.imgix.net/2249/5d91-1...
# 3044538  138592.0     200  http://i.dailymail.co.uk/i/pix/2017/04/21/11/3...
# 2182076  169257.0     200  http://i.dailymail.co.uk/i/pix/2017/09/11/12/4...
# 1504394       NaN     200  http://l7.alamy.com/zooms/32f6eb5d9bc74ff999ce...

# %%
df['mimetype'] = df['mimetype'].str.split(';').str[0]

# %%
pd.DataFrame(df.groupby('mimetype')['url'].count()).reset_index(level=0).sort_values(by='url', ascending=False)
# Out:
#                                              mimetype      url
# 36                                         image/jpeg  2647202
# 55                                          text/html   126369
# 59                                         text/plain    15772
# 40                                          image/jpg     3231
# 20                           application/octet-stream     2344
# 25                                    application/xml     1944
# 42                                          image/png     1753
# 35                                          image/gif     1702
# 32                                         image/JPEG     1155
# 26                                binary/octet-stream      444
# 18                                   application/json      413
# 51                                                jpg      327
# 41                                        image/pjpeg      114
# 27                                              image      104
# 33                                         image/Jpeg       55
# 6                                          Image/jpeg       41
# 60                                           text/xml       33
# 16                         application/force-download       24
# 23                      application/x-shockwave-flash       20
# 15                               application/download       17
# 31                                            image/*       16
# 8                                                JPEG       15
# 21                application/octet-stream, text/html       14
# 12                                       [image/jpeg]       14
# 52                                multipart/form-data       13
# 9                                                 JPG       10
# 2                                                   2       10
# 37                             image/jpeg, image/jpeg        9
# 49                                        images/jpeg        8
# 44                                         image/text        7
# ..                                                ...      ...
# 61                                        Â image/gif        4
# 4                                          IMAGE/JPEG        4
# 5                                          Image/Jpeg        4
# 58                               text/html, text/html        3
# 24                  application/x-www-form-urlencoded        3
# 57                              text/html, image/jpeg        2
# 56                                         text/html         2
# 48                                         image\jpeg        2
# 34                                          image/bmp        2
# 10                                           S3Object        2
# 39                              image/jpeg,image/jpeg        2
# 29                                        image, jpeg        2
# 3                                     Application/jpg        2
# 50                                               jpeg        1
# 54                                          text.html        1
# 53                                                png        1
# 7                                           Image/jpg        1
# 1                                ('image/jpeg', none)        1
# 47                                      image/x-https        1
# 11  [#<MIME::Type:0x00000002296808 @content_type="...        1
# 14                                    application/JPG        1
# 45                                         image/tiff        1
# 17                                    application/gif        1
# 43                                      image/svg+xml        1
# 19                                  application/octet        1
# 22                                   application/perl        1
# 38                              image/jpeg, text/html        1
# 28                                       image%2Fjpeg        1
# 30                                             image/        1
# 0                  #<Mime::NullType:0x007f6f9ecb31c0>        1
#
# [62 rows x 2 columns]

# %%
by_status = df[df['status']!=200][['status','url']]
by_status = by_status.groupby('status').count()
by_status = pd.DataFrame(by_status).reset_index(level=0)
by_status['status'] = by_status['status'].apply(lambda x: http_label(x))
by_status.set_index("status",drop=True,inplace=True)

print("Total errors from HEAD requests:", sum(by_status['url']))
by_status.sort_values(by='url').head(20).plot.barh()
by_status.sort_values(by='url',ascending=False).head(20)
# Out:
# Total errors from HEAD requests: 195627
#                                        url
# status
# Not_Found (404)                      64048
# Request_Timeout (408)                53168
# Forbidden (403)                      42082
# Method_Not_Allowed (405)             24939
# Service_Unavailable (503)             2807
# Bad_Request (400)                     2519
# Internal_Server_Error (500)           1644
# Other Unexpected Status (520)         1508
# Gone (410)                            1395
# Bad_Gateway (502)                      512
# Too_Many_Requests (429)                399
# Unauthorized (401)                     212
# Unavailable_for_Legal_Reasons (451)    101
# No_Content (204)                        96
# Other Unexpected Status (521)           54
# Unsupported_Media_Type (415)            43
# Not_Acceptable (406)                    21
# Other Unexpected Status (523)           17
# Other Unexpected Status (526)           13
# Not_Implemented (501)                    9

# %%
# File Sizes:
file_sizes = np.log(df[(df['size']> 0) & (df['mimetype'].str.contains('image'))]['size'].dropna())
print(len(file_sizes), 'images')

formatter = matplotlib.ticker.FuncFormatter(filesize)
plt.figure(figsize=(14,8))
ax = sns.violinplot(x=file_sizes, orient='v', inner='quartile', bw=0.01, palette='Set2')
ax.yaxis.set_major_formatter(formatter)
ax.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(1))
plt.show()
# Out:
# 2013944 images
# /home/igor/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /home/igor/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)
