# %%
import torch

from PIL import Image
from lavis.models import load_model_and_preprocess
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /opt/conda/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZN3c106SymInt8toSymIntENS_13intrusive_ptrINS_14SymIntNodeImplENS_6detail34intrusive_target_default_null_typeIS2_EEEE
#   warn(f"Failed to load image Python extension: {e}")
# /opt/conda/lib/python3.8/site-packages/diffusers/models/cross_attention.py:30: FutureWarning: Importing from cross_attention is deprecated. Please import from diffusers.models.attention_processor instead.
#   deprecate(

# %%
torch.cuda.is_available()
# Out:
# True

# %%
model, vis_preprocess, txt_preprocess = load_model_and_preprocess("blip_diffusion", "base", device="cuda", is_eval=True)
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# /opt/conda/lib/python3.8/site-packages/diffusers/configuration_utils.py:215: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# No ctx_embeddings_cache found in /export/share/dongxuli/zerobooth/500000-renamed/

# %%
src_subject = "cat"
tgt_subject = "dog"
prompt = "sit on sofa"
# prompt = "at the grand canyon"

# src_subject = txt_preprocess["eval"](src_subject)
# tgt_subject = txt_preprocess["eval"](tgt_subject)
src_subject = [txt_preprocess["eval"](src_subject)]
tgt_subject = [txt_preprocess["eval"](tgt_subject)]
prompt = [txt_preprocess["eval"](prompt)]

image = Image.open("../images/dog.png").convert("RGB")
input_images = vis_preprocess["eval"](image).unsqueeze(0).cuda()

raw_image = Image.open("../images/cat-sofa.png").convert("RGB")

display(image.resize((256, 256)))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F1D6A0175E0>

# %%
samples = {
    "input_images": input_images,
    "src_subject": src_subject,
    "tgt_subject": tgt_subject,
    "prompt": prompt,
    "raw_image": raw_image,
}

# %%
iter_seed = 88871
guidance_scale = 7.5
# guidance_scale = 1.0
num_inference_steps = 50
negative_prompt = "over-exposure, under-exposure, saturated, duplicate, out of frame, lowres, cropped, worst quality, low quality, jpeg artifacts, morbid, mutilated, out of frame, ugly, bad anatomy, bad proportions, deformed, blurry, duplicate"

output = model.edit(
    samples,
    seed=iter_seed,
    guidance_scale=guidance_scale,
    num_inference_steps=num_inference_steps,
    neg_prompt=negative_prompt,
)

print("=" * 30)
print("Before editing:")
display(output[0])

print("After editing:")
display(output[1])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb Cell 6 in 7
#       <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> num_inference_steps = 50
#       <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> negative_prompt = "over-exposure, under-exposure, saturated, duplicate, out of frame, lowres, cropped, worst quality, low quality, jpeg artifacts, morbid, mutilated, out of frame, ugly, bad anatomy, bad proportions, deformed, blurry, duplicate"
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> output = model.edit(
#       <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     samples,
#       <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     seed=iter_seed,
#      <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>     guidance_scale=guidance_scale,
#      <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     num_inference_steps=num_inference_steps,
#      <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     neg_prompt=negative_prompt,
#      <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> print("=" * 30)
#      <a href='vscode-notebook-cell://ssh-remote%2Blocalhost/export/home/workspace/LAVIS-Diffusion/LAVIS/projects/blip-diffusion/notebooks/editing_real.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> print("Before editing:")
#
# File /opt/conda/lib/python3.8/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /export/home/workspace/LAVIS-Diffusion/LAVIS/lavis/models/blip_diffusion_models/blip_diffusion.py:297, in BlipDiffusion.edit(self, samples, latents, guidance_scale, height, width, seed, num_inference_steps, neg_prompt)
#     294 if latents is None:
#     295     latents = self.get_image_latents(raw_image, rng_generator=None)
# --> 297 latents = self._forward_ddim(
#     298     samples=samples,
#     299     latents=latents,
#     300     seed=seed,
#     301     guidance_scale=1.0,
#     302     height=height,
#     303     width=width,
#     304     num_inference_steps=num_inference_steps,
#     305 )
#     307 recon_image = self._edit_with_latent(
#     308     samples=samples,
#     309     latents=latents,
#    (...)
#     316     use_ddim=True,
#     317 )
#     319 return recon_image
#
# File /opt/conda/lib/python3.8/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /export/home/workspace/LAVIS-Diffusion/LAVIS/lavis/models/blip_diffusion_models/blip_diffusion.py:365, in BlipDiffusion._forward_ddim(self, samples, latents, guidance_scale, height, width, seed, num_inference_steps)
#     362 iterator = tqdm.tqdm(reversed(scheduler.timesteps))
#     364 for i, t in enumerate(iterator):
# --> 365     latents = self._add_noise_latent_step(
#     366         latents=latents,
#     367         t=t,
#     368         text_embeddings=text_embeddings,
#     369         height=height,
#     370         width=width,
#     371         guidance_scale=guidance_scale,
#     372     )
#     374 return latents
#
# File /export/home/workspace/LAVIS-Diffusion/LAVIS/lavis/models/blip_diffusion_models/blip_diffusion.py:830, in BlipDiffusion._add_noise_latent_step(self, latents, t, text_embeddings, guidance_scale, height, width)
#     825 latent_model_input = (
#     826     torch.cat([latents] * 2) if do_classifier_free_guidance else latents
#     827 )
#     829 # predict the noise residual
# --> 830 noise_pred = self._predict_noise(
#     831     t=t,
#     832     latent_model_input=latent_model_input,
#     833     text_embeddings=text_embeddings,
#     834     width=width,
#     835     height=height,
#     836 )
#     838 scheduler = self.ddim_scheduler
#     840 prev_timestep = (
#     841     t - scheduler.config.num_train_timesteps // scheduler.num_inference_steps
#     842 )
#
# File /export/home/workspace/LAVIS-Diffusion/LAVIS/lavis/models/blip_diffusion_models/blip_diffusion.py:215, in BlipDiffusion._predict_noise(self, t, latent_model_input, text_embeddings, width, height, cond_image)
#     212 else:
#     213     down_block_res_samples, mid_block_res_sample = None, None
# --> 215 noise_pred = self.unet(
#     216     latent_model_input,
#     217     timestep=t,
#     218     encoder_hidden_states=text_embeddings,
#     219     down_block_additional_residuals=down_block_res_samples,
#     220     mid_block_additional_residual=mid_block_res_sample,
#     221 )["sample"]
#     223 return noise_pred
#
# File /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.8/site-packages/diffusers/models/unet_2d_condition.py:773, in UNet2DConditionModel.forward(self, sample, timestep, encoder_hidden_states, class_labels, timestep_cond, attention_mask, cross_attention_kwargs, down_block_additional_residuals, mid_block_additional_residual, return_dict)
#     770     upsample_size = down_block_res_samples[-1].shape[2:]
#     772 if hasattr(upsample_block, "has_cross_attention") and upsample_block.has_cross_attention:
# --> 773     sample = upsample_block(
#     774         hidden_states=sample,
#     775         temb=emb,
#     776         res_hidden_states_tuple=res_samples,
#     777         encoder_hidden_states=encoder_hidden_states,
#     778         cross_attention_kwargs=cross_attention_kwargs,
#     779         upsample_size=upsample_size,
#     780         attention_mask=attention_mask,
#     781     )
#     782 else:
#     783     sample = upsample_block(
#     784         hidden_states=sample, temb=emb, res_hidden_states_tuple=res_samples, upsample_size=upsample_size
#     785     )
#
# File /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.8/site-packages/diffusers/models/unet_2d_blocks.py:1858, in CrossAttnUpBlock2D.forward(self, hidden_states, res_hidden_states_tuple, temb, encoder_hidden_states, cross_attention_kwargs, upsample_size, attention_mask)
#    1856     else:
#    1857         hidden_states = resnet(hidden_states, temb)
# -> 1858         hidden_states = attn(
#    1859             hidden_states,
#    1860             encoder_hidden_states=encoder_hidden_states,
#    1861             cross_attention_kwargs=cross_attention_kwargs,
#    1862         ).sample
#    1864 if self.upsamplers is not None:
#    1865     for upsampler in self.upsamplers:
#
# File /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.8/site-packages/diffusers/models/transformer_2d.py:265, in Transformer2DModel.forward(self, hidden_states, encoder_hidden_states, timestep, class_labels, cross_attention_kwargs, return_dict)
#     263 # 2. Blocks
#     264 for block in self.transformer_blocks:
# --> 265     hidden_states = block(
#     266         hidden_states,
#     267         encoder_hidden_states=encoder_hidden_states,
#     268         timestep=timestep,
#     269         cross_attention_kwargs=cross_attention_kwargs,
#     270         class_labels=class_labels,
#     271     )
#     273 # 3. Output
#     274 if self.is_input_continuous:
#
# File /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.8/site-packages/diffusers/models/attention.py:331, in BasicTransformerBlock.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, timestep, cross_attention_kwargs, class_labels)
#     325     norm_hidden_states = (
#     326         self.norm2(hidden_states, timestep) if self.use_ada_layer_norm else self.norm2(hidden_states)
#     327     )
#     328     # TODO (Birch-San): Here we should prepare the encoder_attention mask correctly
#     329     # prepare attention mask here
# --> 331     attn_output = self.attn2(
#     332         norm_hidden_states,
#     333         encoder_hidden_states=encoder_hidden_states,
#     334         attention_mask=encoder_attention_mask,
#     335         **cross_attention_kwargs,
#     336     )
#     337     hidden_states = attn_output + hidden_states
#     339 # 3. Feed-forward
#
# File /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.8/site-packages/diffusers/models/attention_processor.py:267, in Attention.forward(self, hidden_states, encoder_hidden_states, attention_mask, **cross_attention_kwargs)
#     263 def forward(self, hidden_states, encoder_hidden_states=None, attention_mask=None, **cross_attention_kwargs):
#     264     # The `Attention` class can call different attention processors / attention functions
#     265     # here we simply pass along all tensors to the selected processor class
#     266     # For standard processors that are defined here, `**cross_attention_kwargs` is empty
# --> 267     return self.processor(
#     268         self,
#     269         hidden_states,
#     270         encoder_hidden_states=encoder_hidden_states,
#     271         attention_mask=attention_mask,
#     272         **cross_attention_kwargs,
#     273     )
#
# File /export/home/workspace/LAVIS-Diffusion/LAVIS/lavis/models/blip_diffusion_models/ptp_utils.py:556, in P2PCrossAttnProcessor.__call__(self, attn, hidden_states, encoder_hidden_states, attention_mask)
#     554 # one line change
#     555 if self.controller is not None:
# --> 556     self.controller(attention_probs, is_cross, self.place_in_unet)
#     558 hidden_states = torch.bmm(attention_probs, value)
#     559 hidden_states = attn.batch_to_head_dim(hidden_states)
#
# File /export/home/workspace/LAVIS-Diffusion/LAVIS/lavis/models/blip_diffusion_models/ptp_utils.py:99, in AttentionControl.__call__(self, attn, is_cross, place_in_unet)
#      97     self.cur_att_layer = 0
#      98     self.cur_step += 1
# ---> 99     self.between_steps()
#     100 return attn
#
# File /export/home/workspace/LAVIS-Diffusion/LAVIS/lavis/models/blip_diffusion_models/ptp_utils.py:137, in AttentionStore.between_steps(self)
#     135     for key in self.attention_store:
#     136         for i in range(len(self.attention_store[key])):
# --> 137             self.attention_store[key][i] += self.step_store[key][i]
#     138 self.step_store = self.get_empty_store()
#
# RuntimeError: The size of tensor a (16) must match the size of tensor b (4) at non-singleton dimension 0

# %%
output[0].size
# Out:
# (512, 512)
